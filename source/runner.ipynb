# %%
import preprocess
import aggregation
import Configurations as configs
from aggligation import AggCategoricalData, AggTopicData

# %%
preprocess.execute()

# %%
agg_categorical = aggregation.AggCategoricalData(
    configs.AggConfiguration.DataPath,
    configs.AggConfiguration.HoldingNum,
    configs.AggConfiguration.AggTargetCols
)
agg_categorical.execute()

# %%
agg_topic = aggregation.AggTopicData(
    configs.AggConfiguration.DataPath,
    configs.AggConfiguration.AggTopicCol
)
agg_topic.execute()
